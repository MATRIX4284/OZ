# %%
import pdfplumber

with pdfplumber.open("../PDF_SOURCE/Kubernetes_in_Action.pdf") as pdf:
    pdf.pages
    print(len(pdf.pages))
# Out:
# 628

# %%
pdf_file=pdfplumber.open("../PDF_SOURCE/Kubernetes_in_Action.pdf")

# %%
for idx in range(87,569):
    text=pdf_file.pages[idx].extract_text_lines(layout=True)
    
    print(text)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
text
# Out:
# [{'text': 'Using kubectl with multiple clusters or namespaces 537',
#   'x0': 179.93901171000005,
#   'top': 26.789999999999964,
#   'x1': 474.10170564,
#   'bottom': 35.789999999999964,
#   'chars': [{'matrix': (9.0237, 0.0, 0, 9, 179.93901171000005, 632.64),
#     'fontname': 'LBBJCA+NewBaskerville-BoldItalic',
#     'adv': 0.7000000000000001,
#     'upright': True,
#     'x0': 179.93901171000005,
#     'y0': 630.21,
#     'x1': 186.25560171000004,
#     'y1': 639.21,
#     'width': 6.316589999999991,
#     'height': 9.0,
#     'size': 9.0,
#     'mcid': None,
#     'tag': None,
#     'object_type': 'char',
#     'page_number': 569,
#     'ncs': 'DeviceRGB',
#     'text': 'U',
#     'stroking_color': None,
#     'stroking_pattern': None,
#     'non_stroking_color': (0, 0, 0),
#     'non_stroking_pattern': None,
#     'top': 26.789999999999964,
#     'bottom': 35.789999999999964,
#     'doctop': 378314.79},
#    {'matrix': (9.0237, 0.0, 0, 9, 186.24116379000006, 632.64),
# ...

# %%
for idx in range(87,569):
    #text=pdf_file.pages[idx].extract_text(layout=True)
    
    #print(text)
    print(pdf_file.pages[idx].images)
    
    
    #pdf_file.pages[idx].crop([409.727,270.038,440.688,282.959], relative=False, strict=True)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
from PyPDF2 import PdfReader

reader = PdfReader("../PDF_SOURCE/Kubernetes_in_Action.pdf")

# %%
len(reader.pages)
# Out:
# 628

# %%
for idx in range(87,565):
    page=reader.pages[idx]
    text=page.extract_text()
    #print(text)
    count = 0

    for image_file_object in page.images:
        with open(str(count) + image_file_object.name, "wb") as fp:
            fp.write(image_file_object.data)
            count += 1
