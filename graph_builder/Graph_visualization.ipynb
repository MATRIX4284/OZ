# %%
#Importing Required Libraries Used for Graph Visualization##################################
from pyvis.network import Network
import networkx as nx

# %%
graph_output_dir="./graph_output_networkx/"
graph_phase2="Graph_Stage2_with_entity_desc_embeddings.graphml"

# %%
G=nx.read_graphml(graph_output_dir+graph_phase2)

# %%
G.nodes
# Out:
# NodeView(('Kubernetes_in_Action.pdf', '89', '1', 'text_0', '90', 'text_1', '91', 'text_2', '92', 'text_3', '93', 'text_4', '94', 'text_5', '95', 'text_6', '96', 'text_7', '97', 'text_8', '98', 'text_9', '99', 'text_10', '100', 'text_11', '101', 'text_12', '102', 'text_13', '103', 'text_14', '104', 'text_15', '105', 'text_16', '106', 'text_17', '107', 'text_18', '108', 'text_19', '109', 'text_20', '110', 'text_21', '111', 'text_22', '112', 'text_23', '113', 'text_24', '114', 'text_25', '115', 'text_26', '116', 'text_27', '117', 'text_28', '118', 'text_29', '119', 'text_30', '120', 'text_31', '121', 'text_32', '122', 'text_33', '123', 'text_34', '124', 'text_35', '125', 'text_36', '126', 'text_37', '127', 'text_38', '128', 'text_39', '129', 'text_40', '130', 'text_41', '131', 'text_42', '132', 'text_43', '133', 'text_44', '134', 'text_45', '135', 'text_46', '136', 'text_47', '137', 'text_48', '138', 'text_49', '139', 'text_50', '140', 'text_51', '141', 'text_52', '142', 'text_53', '143
# ...

# %%
from pyvis.network import Network
####The main contents of Kubernets In Action book is contained from page 87 to 565####
####Thats why we will only take the sliced portion i.e. from page 87 to 565 of the pdf dictionary list#####
nt = Network('400px', '1000px',notebook=True,cdn_resources='in_line')
# populates the nodes and edges data structures
nt.from_nx(G)
nt.toggle_physics(True)
nt.show('Graph_Stage2_with_entity_desc_embeddings.html')
# Out:
# Graph_Stage2_with_entity_desc_embeddings.html
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 8
#       6 nt.from_nx(G)
#       7 nt.toggle_physics(True)
# ----> 8 nt.show('Graph_Stage2_with_entity_desc_embeddings.html')
#
# File ~/mambaforge-pypy3/envs/search_agent_poc/lib/python3.10/site-packages/pyvis/network.py:546, in Network.show(self, name, local, notebook)
#     544 print(name)
#     545 if notebook:
# --> 546     self.write_html(name, open_browser=False,notebook=True)
#     547 else:
#     548     self.write_html(name, open_browser=True)
#
# File ~/mambaforge-pypy3/envs/search_agent_poc/lib/python3.10/site-packages/pyvis/network.py:515, in Network.write_html(self, name, local, notebook, open_browser)
#     513 getcwd_name = name
#     514 check_html(getcwd_name)
# --> 515 self.html = self.generate_html(notebook=notebook)
# ...
