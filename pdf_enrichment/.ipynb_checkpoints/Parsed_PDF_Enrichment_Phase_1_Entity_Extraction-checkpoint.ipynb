# %%
##Python venv: search_agent_poc

# %%
##This module will take the serialized dictionary got out of PDF Parsing ann try to extract
##Semantic Knowldge like identifying 
## 1.Important Objects/Entities
## 2.Deduplicate Entities
## 3.Extracting Relations
## 4.Extract the main Ideas/Topics around Each Page
## 5.Link the different topics via diffrent entities/Objects
## 6.Break down the document by pages instead of Chunks .
## 7.If a page does not fit a chunk then chunk them extract information and then deduplicate the information across
## the page.

#Next Steps:
## 5.Try to Seggregate the BigPDF on Sections.
## 8.Try To Find Common Objects or ideas that link these sections.
## 9.Try

# %%
import pickle
import pandas as pd
#rag_test_input_path='/home/matrix4284/MY_GEN_AI_PROJECTS/RAG/GraphRAG/graphrag-local-ollama/ragtest/input/'+file_name
import os
# importing shutil module
import shutil

from langchain_community.chat_models import ChatOllama

from langchain_community.embeddings import HuggingFaceEmbeddings

from langchain_community.embeddings.sentence_transformer import (
    SentenceTransformerEmbeddings,
)

from sentence_transformers import SentenceTransformer
#embeddings = SentenceTransformer("all-MiniLM-L6-v2")

from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma

import json
import operator
from typing import Annotated, Sequence, TypedDict

from langchain import hub
from langchain.prompts import PromptTemplate
from langchain_community.vectorstores import Chroma
from langchain_core.messages import BaseMessage, FunctionMessage
from langchain_core.output_parsers import StrOutputParser
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_core.runnables import RunnablePassthrough
from langchain_community.chat_models import ChatOllama
from langchain_core.output_parsers import JsonOutputParser
import json
import operator
from typing import Annotated, Sequence, TypedDict

from langchain import hub
from langchain.prompts import PromptTemplate
from langchain_community.vectorstores import Chroma
from langchain_core.messages import BaseMessage, FunctionMessage
from langchain_core.output_parsers import StrOutputParser
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_core.runnables import RunnablePassthrough
from langchain_community.chat_models import ChatOllama
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.output_parsers import StrOutputParser
from langchain.output_parsers import XMLOutputParser

# %%
model_name="llama3.1"
book_text=''
page_text=''
file_name='Kubernetes_in_action_text_only'
extension='.txt'
start_page_idx=315
end_page_index=479
pdf_parsed_output_dir = '../pdf_parsing/parsed_pdf_output_pickle/'
pdf_enrichment_output_dir = './pdf_enriched_output/'
#full_filename=file_name+'_'+str(page_idx)+extension
#full_filename

# %%
#LLM Model for Prompt Tuning
llm = ChatOllama(base_url="http://192.168.50.100:11434",model=model_name,temperature=0.2)

#embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
model_kwargs = {'device': 'cpu'}

embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2",model_kwargs = model_kwargs)

##Define Vectorstore
vectorstore = Chroma(embedding_function=embeddings, persist_directory="./chroma_kubernetes_in_action")
# Out:
# /home/matrix4284/mambaforge-pypy3/envs/search_agent_poc/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(
# /home/matrix4284/mambaforge-pypy3/envs/search_agent_poc/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 0.4. An updated version of the class exists in the langchain-chroma package and should be used instead. To use it run `pip install -U langchain-chroma` and import as `from langchain_chroma import Chroma`.
#   warn_deprecated(

# %%
#Ininitial Load From Parsed Content (deserialized data)
#with open(pdf_parsed_output_dir+'pdf_content_dict_stage1.pickle', 'rb') as handle:
#    document_dict_deserialized = pickle.load(handle)
#document_dict_deserialized=document_dict_deserialized[87:566]

###Intermediate Load in case of errors
with open(pdf_enrichment_output_dir+'pdf_enriched_content_dict_phase1_entity_extraction_314.pickle', 'rb') as handle:
    document_dict_deserialized = pickle.load(handle)

# %%
len(document_dict_deserialized)
# Out:
# 479

# %%
##Definitions of Individual Enrichment Modules######

# Function to reverse a string
def reverse(string):
    string = string[::-1]
    return string

def extract_entities_per_page(page_text):
    
    
    parser = XMLOutputParser()

# Prompt
    prompt = PromptTemplate(
            template="""You are a computer technology expert who has mastery in Kubernetes,Docker\n
            Machine Larning,Generative AI,Natural Language Understanding and Computer Vision.\n
            You have to deeply study a document page related to a particular technology and extract \n
            the main entities or objects from the document.The entities or objects can be anything surrounding \n
            technology in which your expetise lies.By Objects or entities i mean it can be a programming Language,\n
            command,framework,database,process,cache,controller,qeueues,schedulers,errors,exceptions or any \n
            components related to technology. \n
            Never extract page number or any kind of number as entity. \n
            surrounding the technology.Please output in form of list of json where each extracted entity will be \n
            represented by a json along with description and category.\n
            The category name can be like \n
            hardware,software,network,application,database,process,thread,container etc.Mention the category name \n
            in third bracket. \n
            After extracting all the entities along with their description and category format as per rules below: \n
            1.For each entity create a json with 3 keys "entity","description" and "category". \n
            2.Each extracted entity must be enlosed within double quotes. \n
            3.There should not be any unterimnated string for "entity","description" and "category".In case it is \n
            unterminated due to any reason put the ending double quote to it.\n
            3.Each extracted entity must be a valid word,phrase or a complete command.\n
            4.Extracted entity should never be a character,part of a word,aplhabet,number or any alphaneumeric.\n
            After all the entities of the page are extracted where each entity is a json then only collate all the entity json \m
            into a list of json.
            5.If any of the extracted entity,description value contain character ':',handle it as a part of entity \n
            or decription ,dont use the character ':' found in entity or description as  a delimiter.\n
            Output the collated list of json where each entity is represented by json. \n
            Do not output anything other than the list of json neither heading/decsription before the list of json\n
            nor any decsription/footer below the json \n
            Here is the document page: \n\n {context} \n\n""",
            input_variables=["context"],
            partial_variables={"format_instructions": parser.get_format_instructions()},
    )

    # Chain
    #Commented out By Kaustav 20/08/2024 as str output parser is giving some unwanted text #####
    chain = prompt | llm | StrOutputParser()
   
    




    #Trying out XML Output parser by Kautsva added 20/08/2024####
    #chain = prompt | llm | parser
    
    

    # Score
    #filtered_docs = []
    
    #print("Page Text")
    #print(page_text)

    output = chain.invoke(
        {
                "context": page_text,
        }
    )
    
    #print('Relationship Output from LLM"')
    #print(output)
    
    if '[' in output:
        json_output=output.split('[')[1]
        json_output='['+json_output
    else:    
        json_output='['+json_output
    
    #print('JSON OUTPUT:')
    #print(json_output)
    
    

    json_output=reverse(json_output)
    
    if ']' in json_output:
        json_output=json_output.split(']')[1]
        json_output=reverse(json_output)
        json_output= json_output + ']'
    else:
        json_output=reverse(json_output)
        json_output= json_output + ']'
    
    return json_output
    
    #return page_output_json
    #return output

def entity_collector_per_page(entity_lst):

    entities=[]
    
    for entity in entity_lst:
        print("Entity:")
        print(entity)
        entity_name=entity['entity']
        entities.append(entity_name)
    return list(set(entities))

# %%
######This code enrcihes the PDF page by page and while doing so it fails after processing 20 to 50 pages####
######currently we are manually tackling this problem by making the pdf dict list into aglobal variable######
######After the llm fails we take the index of the last page done and save the pdf dict list uptil that ####
#####Then as of now i am manually restarting the by loading the saved pdf dict list as the source pdf and ###
#####Using the last done pdf page index +1 as the starting index.So (last Done page Index + 1) is the ######
###starting index###
####The maximum page has been given as 565 as that is the last page where the main content of the document###
####resides.In case of the book Kubernetes in action it is 565.##############################################
####If this is batch process then the last page can be manually seen and used as the variable else one can ####
#####also go for the pdf enrichment of all the pages of the book#############################################

###This manual thing needs to be automated by either langraph or by using agents framework##################

def enrich_page(page_idx):
    
    print("Page Number")
    print(page_idx)
    
    page_text=document_dict_deserialized[page_idx]['text']
    
    ##Entity Extraction Enrichment
    page_entity_lst_dict=extract_entities_per_page(page_text)
    
    #print("Page Entity List Dictionary")
    #print(page_entity_lst_dict)
    
    print("Page Entity List Dictionary Cleaned")
    print(page_entity_lst_dict)
    
    page_entity_lst_json=json.loads(page_entity_lst_dict)
    document_dict_deserialized[page_idx]['entities']=page_entity_lst_json
    
    ##Collate entity list per page into unique Entities
    
    entity_lst=entity_collector_per_page(page_entity_lst_json)
    
    ##Relationship Extraction Enrichment
    #page_relationship_lst_dict=extract_relationship_per_page(page_text,entity_lst)
    
    #print("Page Relationship List Dictionary")
    #print(page_entity_lst_dict)
    
    #document_dict_deserialized[page_idx]['relationships']=page_relationship_lst_dict
    print("Done for page "+str(page_idx))
    return page_idx

# %%
for idx in range(start_page_idx,end_page_index):
   
        enrich_page(idx)
# Out:
# Page Number
# 220
# Page Entity List Dictionary Cleaned
# [
#   {"entity": "Deployments", "description": "A way to update apps declaratively", "category": "software"},
#   {"entity": "Pods", "description": "The smallest unit of deployment in Kubernetes", "category": "container"},
#   {"entity": "Readiness Probe", "description": "A mechanism to prevent bad versions from being rolled out", "category": "process"},
#   {"entity": "curl", "description": "A command-line tool for transferring data with URL syntax", "category": "command"},
#   {"entity": "Service", "description": "An abstraction layer that provides a network identity and load balancing for accessing applications in Kubernetes", "category": "application"},
#   {"entity": "ReplicaSet", "description": "A controller that ensures a specified number of replicas are running at any given time", "category": "controller"},
#   {"entity": "Deployment", "description": "A higher-level abstraction that provides declarative updates to ReplicaSets and Pods", "category": "software"},
#   {"entity": "maxSurge", "description": "The maximum number of new replicas that can be created during a rollout", "category": "property"},
#   {"entity": "maxUnavailable", "description": "The maximum number of unavailable replicas allowed during a rollout", "category": "property"},
#   {"entity": "rollout status", "description": "A command to display the current state of a deployment's rollout process", "category": "command"}
# ]
# Entity:
# {'entity': 'Deployments', 'description': 'A way to update apps declaratively', 'category': 'software'}
# Entity:
# {'entity': 'Pods', 'description': 'The smallest unit of deployment in Kubernetes', 'category': 'container'}
# Entity:
# {'entity': 'Readiness Probe', 'description': 'A mechanism to prevent bad versions from being rolled out', 'category': 'process'}
# Entity:
# {'entity': 'curl', 'description': 'A command-line tool for transferring data with URL syntax', 'category': 'command'}
# Entity:
# {'entity': 'Service', 'description': 'An abstraction layer that provides a network identity and load balancing for accessing applications in Kubernetes', 'category': 'application'}
# Entity:
# {'entity': 'ReplicaSet', 'description': 'A controller that ensures a specified number of replicas are running at any given time', 'category': 'controller'}
# Entity:
# {'entity': 'Deployment', 'description': 'A higher-level abstraction that provides declarative updates to ReplicaSets and Pods', 'category': 'software'}
# Entity:
# {'entity': 'maxSurge', 'description': 'The maximum number of new replicas that can be created during a rollout', 'category': 'property'}
# Entity:
# {'entity': 'maxUnavailable', 'description': 'The maximum number of unavailable replicas allowed during a rollout', 'category': 'property'}
# Entity:
# {'entity': 'rollout status', 'description': "A command to display the current state of a deployment's rollout process", 'category': 'command'}
# Done for page 220
# Page Number
# 221
# Page Entity List Dictionary Cleaned
# [
#   {"entity": "deployment", "description": "A Kubernetes resource that manages the rollout of new versions of an application.", "category": "application"},
#   {"entity": "readiness probe", "description": "A mechanism to determine if a pod is ready to serve traffic.", "category": "process"},
#   {"entity": "minReadySeconds", "description": "The minimum number of seconds that the rollout must wait before considering a new version available.", "category": "property"},
#   {"entity": "kubectl describe deployment", "description": "A command to display detailed information about a Deployment resource.", "category": "command"},
#   {"entity": "ProgressDeadlineExceeded", "description": "A condition indicating that the rollout has exceeded its deadline and is considered failed.", "category": "condition"},
#   {"entity": "progressDeadlineSeconds", "description": "The time in seconds after which the Deployment is considered failed if no progress is made.", "category": "property"},
#   {"entity": "extensions/v1beta1", "description": "A version of the Deployments API that does not set a deadline for rollouts.", "category": "API"},
#   {"entity": "kubectl rollout undo deployment", "description": "A command to abort a failed rollout and revert to the previous version.", "category": "command"},
#   {"entity": "Deployment", "description": "A Kubernetes resource that manages the rollout of new versions of an application.", "category": "application"}
# ]
# Entity:
# {'entity': 'deployment', 'description': 'A Kubernetes resource that manages the rollout of new versions of an application.', 'category': 'application'}
# Entity:
# {'entity': 'readiness probe', 'description': 'A mechanism to determine if a pod is ready to serve traffic.', 'category': 'process'}
# Entity:
# {'entity': 'minReadySeconds', 'description': 'The minimum number of seconds that the rollout must wait before considering a new version available.', 'category': 'property'}
# Entity:
# {'entity': 'kubectl describe deployment', 'description': 'A command to display detailed information about a Deployment resource.', 'category': 'command'}
# Entity:
# {'entity': 'ProgressDeadlineExceeded', 'description': 'A condition indicating that the rollout has exceeded its deadline and is considered failed.', 'category': 'condition'}
# Entity:
# {'entity': 'progressDeadlineSeconds', 'description': 'The time in seconds after which the Deployment is considered failed if no progress is made.', 'category': 'property'}
# Entity:
# {'entity': 'extensions/v1beta1', 'description': 'A version of the Deployments API that does not set a deadline for rollouts.', 'category': 'API'}
# Entity:
# {'entity': 'kubectl rollout undo deployment', 'description': 'A command to abort a failed rollout and revert to the previous version.', 'category': 'command'}
# Entity:
# {'entity': 'Deployment', 'description': 'A Kubernetes resource that manages the rollout of new versions of an application.', 'category': 'application'}
# Done for page 221
# Page Number
# 222
# Page Entity List Dictionary Cleaned
# [
#   {"entity": "Kubernetes", "description": "", "category": "software"},
#   {"entity": "ReplicationController", "description": "", "category": "software"},
#   {"entity": "Deployments", "description": "", "category": "software"},
#   {"entity": "pods", "description": "", "category": "software"},
#   {"entity": "Deployment specification", "description": "", "category": "software"},
#   {"entity": "revision history", "description": "", "category": "software"},
#   {"entity": "maxSurge", "description": "", "category": "software"},
#   {"entity": "maxUnavailable", "description": "", "category": "software"},
#   {"entity": "minReadySeconds", "description": "", "category": "software"},
#   {"entity": "readiness probes", "description": "", "category": "software"},
#   {"entity": "kubectl", "description": "", "category": "software"},
#   {"entity": "YAML file", "description": "", "category": "software"},
#   {"entity": "pod template", "description": "", "category": "software"},
#   {"entity": "persistent storage", "description": "", "category": "hardware"}
# ]
# Entity:
# {'entity': 'Kubernetes', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'ReplicationController', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'Deployments', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'pods', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'Deployment specification', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'revision history', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'maxSurge', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'maxUnavailable', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'minReadySeconds', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'readiness probes', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'kubectl', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'YAML file', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'pod template', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'persistent storage', 'description': '', 'category': 'hardware'}
# Done for page 222
# Page Number
# 223
# Page Entity List Dictionary Cleaned
# [{"entity": "StatefulSets", "description": "", "category": "software"},
#  {"entity": "ReplicaSet", "description": "", "category": "software"},
#  {"entity": "pods", "description": "replicated stateless or stateful applications", "category": "application"},
#  {"entity": "persistent storage", "description": "storage for each instance of a replicated pod", "category": "database"},
#  {"entity": "PersistentVolumes", "description": "", "category": "software"},
#  {"entity": "PersistentVolumeClaim", "description": "", "category": "software"},
#  {"entity": "stateless pods", "description": "single-instance or replicated stateless applications", "category": "application"},
#  {"entity": "stateful pods", "description": "utilizing persistent storage", "category": "application"}]
# Entity:
# {'entity': 'StatefulSets', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'ReplicaSet', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'pods', 'description': 'replicated stateless or stateful applications', 'category': 'application'}
# Entity:
# {'entity': 'persistent storage', 'description': 'storage for each instance of a replicated pod', 'category': 'database'}
# Entity:
# {'entity': 'PersistentVolumes', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'PersistentVolumeClaim', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'stateless pods', 'description': 'single-instance or replicated stateless applications', 'category': 'application'}
# Entity:
# {'entity': 'stateful pods', 'description': 'utilizing persistent storage', 'category': 'application'}
# Done for page 223
# Page Number
# 224
# Page Entity List Dictionary Cleaned
# [
#   {"entity": "Replicating stateful pods", "description": "", "category": "process"},
#   {"entity": "ReplicaSets", "description": "create multiple pod replicas from a single pod template", "category": "framework"},
#   {"entity": "Pods", "description": "don’t differ from each other, apart from their name and IP address", "category": "container"},
#   {"entity": "PersistentVolumeClaim", "description": "all replicas of the ReplicaSet will use the exact same", "category": "database"},
#   {"entity": "PersistentVolume", "description": "bound by the claim", "category": "storage"},
#   {"entity": "ReplicaSet", "description": "can’t make each replica use its own separate Persistent-VolumeClaim", "category": "framework"},
#   {"entity": "API objects", "description": "you’ve seen so far make running such a data store possible", "category": "software"},
#   {"entity": "Pods manually", "description": "create pods and have each of them use its own PersistentVolume-Claim", "category": "process"},
#   {"entity": "ReplicaSets per pod instance", "description": "create multiple ReplicaSets—one for each pod with each ReplicaSet’s desired replica count set to one", "category": "framework"},
#   {"entity": "PersistentVolumeClaim", "description": "dedicated PersistentVolumeClaim", "category": "database"},
#   {"entity": "ReplicaSet", "description": "desired replica count set to one", "category": "framework"},
#   {"entity": "Pods", "description": "automatic rescheduling in case of node failures or accidental pod deletions", "category": "container"},
#   {"entity": "Scaling pods", "description": "", "category": "process"}
# ]
# Entity:
# {'entity': 'Replicating stateful pods', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'ReplicaSets', 'description': 'create multiple pod replicas from a single pod template', 'category': 'framework'}
# Entity:
# {'entity': 'Pods', 'description': 'don’t differ from each other, apart from their name and IP address', 'category': 'container'}
# Entity:
# {'entity': 'PersistentVolumeClaim', 'description': 'all replicas of the ReplicaSet will use the exact same', 'category': 'database'}
# Entity:
# {'entity': 'PersistentVolume', 'description': 'bound by the claim', 'category': 'storage'}
# Entity:
# {'entity': 'ReplicaSet', 'description': 'can’t make each replica use its own separate Persistent-VolumeClaim', 'category': 'framework'}
# Entity:
# {'entity': 'API objects', 'description': 'you’ve seen so far make running such a data store possible', 'category': 'software'}
# Entity:
# {'entity': 'Pods manually', 'description': 'create pods and have each of them use its own PersistentVolume-Claim', 'category': 'process'}
# Entity:
# {'entity': 'ReplicaSets per pod instance', 'description': 'create multiple ReplicaSets—one for each pod with each ReplicaSet’s desired replica count set to one', 'category': 'framework'}
# Entity:
# {'entity': 'PersistentVolumeClaim', 'description': 'dedicated PersistentVolumeClaim', 'category': 'database'}
# Entity:
# {'entity': 'ReplicaSet', 'description': 'desired replica count set to one', 'category': 'framework'}
# Entity:
# {'entity': 'Pods', 'description': 'automatic rescheduling in case of node failures or accidental pod deletions', 'category': 'container'}
# Entity:
# {'entity': 'Scaling pods', 'description': '', 'category': 'process'}
# Done for page 224
# Page Number
# 225
# Page Entity List Dictionary Cleaned
# [
#   {"entity": "StatefulSets", "description": "", "category": "software"},
#   {"entity": "ReplicaSet", "description": "", "category": "software"},
#   {"entity": "PersistentVolume", "description": "", "category": "hardware"},
#   {"entity": "Pod", "description": "", "category": "container"},
#   {"entity": "PVC", "description": "", "category": "database"},
#   {"entity": "PV", "description": "", "category": "database"},
#   {"entity": "PersistentVolumeClaim", "description": "", "category": "database"},
#   {"entity": "data directory", "description": "", "category": "process"},
#   {"entity": "storage volume", "description": "", "category": "hardware"}
# ]
# Entity:
# {'entity': 'StatefulSets', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'ReplicaSet', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'PersistentVolume', 'description': '', 'category': 'hardware'}
# Entity:
# {'entity': 'Pod', 'description': '', 'category': 'container'}
# Entity:
# {'entity': 'PVC', 'description': '', 'category': 'database'}
# Entity:
# {'entity': 'PV', 'description': '', 'category': 'database'}
# Entity:
# {'entity': 'PersistentVolumeClaim', 'description': '', 'category': 'database'}
# Entity:
# {'entity': 'data directory', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'storage volume', 'description': '', 'category': 'hardware'}
# Done for page 225
# Page Number
# 226
# Page Entity List Dictionary Cleaned
# [
#   {"entity": "ReplicaSet", "description": "A Kubernetes object that ensures a specified number of replicas (identical pods) are running at any given time.", "category": "software"},
#   {"entity": "Pod", "description": "A single instance of a containerized application in a Kubernetes cluster.", "category": "software"},
#   {"entity": "Service", "description": "An abstraction which defines a logical set of network endpoints, providing a stable IP address for accessing the pods behind it.", "category": "software"},
#   {"entity": "PVC (Persistent Volume Claim)", "description": "A request for storage resources in a Kubernetes cluster.", "category": "software"},
#   {"entity": "PV (Persistent Volume)", "description": "A storage resource in a Kubernetes cluster that can be claimed by a PVC.", "category": "hardware"},
#   {"entity": "ReplicaSet", "description": "A Kubernetes object that ensures a specified number of replicas (identical pods) are running at any given time.", "category": "software"},
#   {"entity": "Pod", "description": "A single instance of a containerized application in a Kubernetes cluster.", "category": "software"},
#   {"entity": "Service", "description": "An abstraction which defines a logical set of network endpoints, providing a stable IP address for accessing the pods behind it.", "category": "software"},
#   {"entity": "PVC (Persistent Volume Claim)", "description": "A request for storage resources in a Kubernetes cluster.", "category": "software"},
#   {"entity": "PV (Persistent Volume)", "description": "A storage resource in a Kubernetes cluster that can be claimed by a PVC.", "category": "hardware"},
#   {"entity": "ReplicaSet", "description": "A Kubernetes object that ensures a specified number of replicas (identical pods) are running at any given time.", "category": "software"},
#   {"entity": "Pod", "description": "A single instance of a containerized application in a Kubernetes cluster.", "category": "software"},
#   {"entity": "Service", "description": "An abstraction which defines a logical set of network endpoints, providing a stable IP address for accessing the pods behind it.", "category": "software"}
# ]
# Entity:
# {'entity': 'ReplicaSet', 'description': 'A Kubernetes object that ensures a specified number of replicas (identical pods) are running at any given time.', 'category': 'software'}
# Entity:
# {'entity': 'Pod', 'description': 'A single instance of a containerized application in a Kubernetes cluster.', 'category': 'software'}
# Entity:
# {'entity': 'Service', 'description': 'An abstraction which defines a logical set of network endpoints, providing a stable IP address for accessing the pods behind it.', 'category': 'software'}
# Entity:
# {'entity': 'PVC (Persistent Volume Claim)', 'description': 'A request for storage resources in a Kubernetes cluster.', 'category': 'software'}
# Entity:
# {'entity': 'PV (Persistent Volume)', 'description': 'A storage resource in a Kubernetes cluster that can be claimed by a PVC.', 'category': 'hardware'}
# Entity:
# {'entity': 'ReplicaSet', 'description': 'A Kubernetes object that ensures a specified number of replicas (identical pods) are running at any given time.', 'category': 'software'}
# Entity:
# {'entity': 'Pod', 'description': 'A single instance of a containerized application in a Kubernetes cluster.', 'category': 'software'}
# Entity:
# {'entity': 'Service', 'description': 'An abstraction which defines a logical set of network endpoints, providing a stable IP address for accessing the pods behind it.', 'category': 'software'}
# Entity:
# {'entity': 'PVC (Persistent Volume Claim)', 'description': 'A request for storage resources in a Kubernetes cluster.', 'category': 'software'}
# Entity:
# {'entity': 'PV (Persistent Volume)', 'description': 'A storage resource in a Kubernetes cluster that can be claimed by a PVC.', 'category': 'hardware'}
# Entity:
# {'entity': 'ReplicaSet', 'description': 'A Kubernetes object that ensures a specified number of replicas (identical pods) are running at any given time.', 'category': 'software'}
# Entity:
# {'entity': 'Pod', 'description': 'A single instance of a containerized application in a Kubernetes cluster.', 'category': 'software'}
# Entity:
# {'entity': 'Service', 'description': 'An abstraction which defines a logical set of network endpoints, providing a stable IP address for accessing the pods behind it.', 'category': 'software'}
# Done for page 226
# Page Number
# 227
# Page Entity List Dictionary Cleaned
# [{"entity": "Kubernetes", "description": "", "category": "software"},
# {"entity": "StatefulSets", "description": "deploying replicated stateful applications", "category": "software"},
# {"entity": "ReplicaSet", "description": "", "category": "software"},
# {"entity": "ReplicationController", "description": "", "category": "software"},
# {"entity": "pets vs. cattle analogy", "description": "", "category": "concept"},
# {"entity": "Stateful pods", "description": "", "category": "application"},
# {"entity": "stateless app", "description": "", "category": "application"},
# {"entity": "ReplicaSet or ReplicationController", "description": "", "category": "software"},
# {"entity": "StatefulSet resource", "description": "", "category": "resource"},
# {"entity": "instances of the application", "description": "", "category": "process"},
# {"entity": "stable name and state", "description": "", "category": "property"},
# {"entity": "non-fungible individuals", "description": "", "category": "concept"},
# {"entity": "ReplicaSet or ReplicationController", "description": "", "category": "software"}]
# Entity:
# {'entity': 'Kubernetes', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'StatefulSets', 'description': 'deploying replicated stateful applications', 'category': 'software'}
# Entity:
# {'entity': 'ReplicaSet', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'ReplicationController', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'pets vs. cattle analogy', 'description': '', 'category': 'concept'}
# Entity:
# {'entity': 'Stateful pods', 'description': '', 'category': 'application'}
# Entity:
# {'entity': 'stateless app', 'description': '', 'category': 'application'}
# Entity:
# {'entity': 'ReplicaSet or ReplicationController', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'StatefulSet resource', 'description': '', 'category': 'resource'}
# Entity:
# {'entity': 'instances of the application', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'stable name and state', 'description': '', 'category': 'property'}
# Entity:
# {'entity': 'non-fungible individuals', 'description': '', 'category': 'concept'}
# Entity:
# {'entity': 'ReplicaSet or ReplicationController', 'description': '', 'category': 'software'}
# Done for page 227
# Page Number
# 228
# Page Entity List Dictionary Cleaned
# [
#   {"entity": "StatefulSets", "description": "A Kubernetes resource that manages stateful applications.", "category": "software"},
#   {"entity": "pods", "description": "The basic execution unit in a containerized environment.", "category": "container"},
#   {"entity": "ReplicaSet", "description": "A Kubernetes resource that ensures a specified number of replicas are running at any given time.", "category": "software"},
#   {"entity": "pod template", "description": "A specification for creating pods in a StatefulSet.", "category": "container"},
#   {"entity": "volumes", "description": "Persistent storage attached to each pod in a StatefulSet.", "category": "storage"},
#   {"entity": "ordinal index", "description": "A zero-based index assigned to each pod created by a StatefulSet.", "category": "process"},
#   {"entity": "hostname", "description": "The name of the machine or container running an application.", "category": "hardware"},
#   {"entity": "Service", "description": "A Kubernetes resource that provides network identity and load balancing for pods.", "category": "software"},
#   {"entity": "headless Service", "description": "A Service that does not provide a public IP address or DNS entry, but is used to provide network identity to pods in a StatefulSet.", "category": "software"},
#   {"entity": "DNS entry", "description": "A record in the Domain Name System (DNS) that maps a hostname to an IP address.", "category": "network"},
#   {"entity": "namespace", "description": "A scope for naming resources in Kubernetes.", "category": "software"}
# ]
# Entity:
# {'entity': 'StatefulSets', 'description': 'A Kubernetes resource that manages stateful applications.', 'category': 'software'}
# Entity:
# {'entity': 'pods', 'description': 'The basic execution unit in a containerized environment.', 'category': 'container'}
# Entity:
# {'entity': 'ReplicaSet', 'description': 'A Kubernetes resource that ensures a specified number of replicas are running at any given time.', 'category': 'software'}
# Entity:
# {'entity': 'pod template', 'description': 'A specification for creating pods in a StatefulSet.', 'category': 'container'}
# Entity:
# {'entity': 'volumes', 'description': 'Persistent storage attached to each pod in a StatefulSet.', 'category': 'storage'}
# Entity:
# {'entity': 'ordinal index', 'description': 'A zero-based index assigned to each pod created by a StatefulSet.', 'category': 'process'}
# Entity:
# {'entity': 'hostname', 'description': 'The name of the machine or container running an application.', 'category': 'hardware'}
# Entity:
# {'entity': 'Service', 'description': 'A Kubernetes resource that provides network identity and load balancing for pods.', 'category': 'software'}
# Entity:
# {'entity': 'headless Service', 'description': 'A Service that does not provide a public IP address or DNS entry, but is used to provide network identity to pods in a StatefulSet.', 'category': 'software'}
# Entity:
# {'entity': 'DNS entry', 'description': 'A record in the Domain Name System (DNS) that maps a hostname to an IP address.', 'category': 'network'}
# Entity:
# {'entity': 'namespace', 'description': 'A scope for naming resources in Kubernetes.', 'category': 'software'}
# Done for page 228
# Page Number
# 229
# Page Entity List Dictionary Cleaned
# [
#   {"entity": "StatefulSets", "description": "deploying replicated stateful applications", "category": "application"},
#   {"entity": "A-0", "description": "fully qualified domain name", "category": "process"},
#   {"entity": "ReplicaSet", "description": "managing pods", "category": "application"},
#   {"entity": "DNS", "description": "looking up StatefulSet's pods' names", "category": "network"},
#   {"entity": "SRV records", "description": "used to discover members of a StatefulSet", "category": "database"},
#   {"entity": "pods", "description": "managed by a StatefulSet or ReplicaSet", "category": "container"},
#   {"entity": "node", "description": "failed or evicted, causing pod loss", "category": "hardware"},
#   {"entity": "StatefulSet A", "description": "replacing lost pods with new instances", "category": "application"},
#   {"entity": "Pod A-0", "description": "instance managed by StatefulSet A", "category": "container"},
#   {"entity": "Pod A-1", "description": "instance managed by StatefulSet A", "category": "container"},
#   {"entity": "ReplicaSet B", "description": "managing pods", "category": "application"},
#   {"entity": "Node 1", "description": "failing or evicting pod", "category": "hardware"},
#   {"entity": "Node 2", "description": "running pod", "category": "hardware"}
# ]
# Entity:
# {'entity': 'StatefulSets', 'description': 'deploying replicated stateful applications', 'category': 'application'}
# Entity:
# {'entity': 'A-0', 'description': 'fully qualified domain name', 'category': 'process'}
# Entity:
# {'entity': 'ReplicaSet', 'description': 'managing pods', 'category': 'application'}
# Entity:
# {'entity': 'DNS', 'description': "looking up StatefulSet's pods' names", 'category': 'network'}
# Entity:
# {'entity': 'SRV records', 'description': 'used to discover members of a StatefulSet', 'category': 'database'}
# Entity:
# {'entity': 'pods', 'description': 'managed by a StatefulSet or ReplicaSet', 'category': 'container'}
# Entity:
# {'entity': 'node', 'description': 'failed or evicted, causing pod loss', 'category': 'hardware'}
# Entity:
# {'entity': 'StatefulSet A', 'description': 'replacing lost pods with new instances', 'category': 'application'}
# Entity:
# {'entity': 'Pod A-0', 'description': 'instance managed by StatefulSet A', 'category': 'container'}
# Entity:
# {'entity': 'Pod A-1', 'description': 'instance managed by StatefulSet A', 'category': 'container'}
# Entity:
# {'entity': 'ReplicaSet B', 'description': 'managing pods', 'category': 'application'}
# Entity:
# {'entity': 'Node 1', 'description': 'failing or evicting pod', 'category': 'hardware'}
# Entity:
# {'entity': 'Node 2', 'description': 'running pod', 'category': 'hardware'}
# Done for page 229
# Page Number
# 230
# Page Entity List Dictionary Cleaned
# [
#   {"entity": "StatefulSets", "description": "A Kubernetes resource that ensures stateful pods have a stable identity", "category": "software"},
#   {"entity": "pods", "description": "Independent running instances of an application", "category": "application"},
#   {"entity": "hostname", "description": "The name by which a pod is reachable", "category": "network"},
#   {"entity": "ReplicaSet", "description": "A Kubernetes resource that ensures a specified number of replicas are running at any given time", "category": "software"},
#   {"entity": "ordinal index", "description": "A unique identifier assigned to each instance of a StatefulSet", "category": "process"},
#   {"entity": "StatefulSets scale down", "description": "The process of reducing the number of instances in a StatefulSet", "category": "process"},
#   {"entity": "scale-down operations", "description": "The act of reducing the number of instances in a StatefulSet", "category": "process"},
#   {"entity": "instances", "description": "Individual running copies of an application or service", "category": "application"},
#   {"entity": "unhealthy instances", "description": "Instances that are not functioning correctly", "category": "application"},
#   {"entity": "storage", "description": "The space on a device where data is stored", "category": "hardware"},
#   {"entity": "dedicated storage", "description": "Storage that is allocated exclusively to a particular instance or service", "category": "hardware"},
#   {"entity": "StatefulSet A", "description": "An example StatefulSet used for demonstration purposes", "category": "software"}
# ]
# Entity:
# {'entity': 'StatefulSets', 'description': 'A Kubernetes resource that ensures stateful pods have a stable identity', 'category': 'software'}
# Entity:
# {'entity': 'pods', 'description': 'Independent running instances of an application', 'category': 'application'}
# Entity:
# {'entity': 'hostname', 'description': 'The name by which a pod is reachable', 'category': 'network'}
# Entity:
# {'entity': 'ReplicaSet', 'description': 'A Kubernetes resource that ensures a specified number of replicas are running at any given time', 'category': 'software'}
# Entity:
# {'entity': 'ordinal index', 'description': 'A unique identifier assigned to each instance of a StatefulSet', 'category': 'process'}
# Entity:
# {'entity': 'StatefulSets scale down', 'description': 'The process of reducing the number of instances in a StatefulSet', 'category': 'process'}
# Entity:
# {'entity': 'scale-down operations', 'description': 'The act of reducing the number of instances in a StatefulSet', 'category': 'process'}
# Entity:
# {'entity': 'instances', 'description': 'Individual running copies of an application or service', 'category': 'application'}
# Entity:
# {'entity': 'unhealthy instances', 'description': 'Instances that are not functioning correctly', 'category': 'application'}
# Entity:
# {'entity': 'storage', 'description': 'The space on a device where data is stored', 'category': 'hardware'}
# Entity:
# {'entity': 'dedicated storage', 'description': 'Storage that is allocated exclusively to a particular instance or service', 'category': 'hardware'}
# Entity:
# {'entity': 'StatefulSet A', 'description': 'An example StatefulSet used for demonstration purposes', 'category': 'software'}
# Done for page 230
# Page Number
# 231
# Page Entity List Dictionary Cleaned
# [{"entity": "PersistentVolumes", "description": "", "category": "database"},
# {"entity": "PersistentVolume-Claims", "description": "", "category": "database"},
# {"entity": "StatefulSets", "description": "", "category": "application"},
# {"entity": "pods", "description": "", "category": "container"},
# {"entity": "PersistentVolumeClaim", "description": "", "category": "database"},
# {"entity": "PersistentVolumes", "description": "", "category": "database"},
# {"entity": "StatefulSet", "description": "", "category": "application"},
# {"entity": "pod template", "description": "", "category": "container"},
# {"entity": "volume claim templates", "description": "", "category": "database"},
# {"entity": "API objects", "description": "", "category": "network"},
# {"entity": "replicas field", "description": "", "category": "application"},
# {"entity": "PVC A-0", "description": "", "category": "database"},
# {"entity": "PV", "description": "", "category": "storage"},
# {"entity": "Pod A-0", "description": "", "category": "container"},
# {"entity": "PVC A-1", "description": "", "category": "database"},
# {"entity": "PV", "description": "", "category": "storage"},
# {"entity": "Pod A-1", "description": "", "category": "container"},
# {"entity": "PVC A-2", "description": "", "category": "database"},
# {"entity": "PV", "description": "", "category": "storage"},
# {"entity": "Pod A-2", "description": "", "category": "container"}]
# Entity:
# {'entity': 'PersistentVolumes', 'description': '', 'category': 'database'}
# Entity:
# {'entity': 'PersistentVolume-Claims', 'description': '', 'category': 'database'}
# Entity:
# {'entity': 'StatefulSets', 'description': '', 'category': 'application'}
# Entity:
# {'entity': 'pods', 'description': '', 'category': 'container'}
# Entity:
# {'entity': 'PersistentVolumeClaim', 'description': '', 'category': 'database'}
# Entity:
# {'entity': 'PersistentVolumes', 'description': '', 'category': 'database'}
# Entity:
# {'entity': 'StatefulSet', 'description': '', 'category': 'application'}
# Entity:
# {'entity': 'pod template', 'description': '', 'category': 'container'}
# Entity:
# {'entity': 'volume claim templates', 'description': '', 'category': 'database'}
# Entity:
# {'entity': 'API objects', 'description': '', 'category': 'network'}
# Entity:
# {'entity': 'replicas field', 'description': '', 'category': 'application'}
# Entity:
# {'entity': 'PVC A-0', 'description': '', 'category': 'database'}
# Entity:
# {'entity': 'PV', 'description': '', 'category': 'storage'}
# Entity:
# {'entity': 'Pod A-0', 'description': '', 'category': 'container'}
# Entity:
# {'entity': 'PVC A-1', 'description': '', 'category': 'database'}
# Entity:
# {'entity': 'PV', 'description': '', 'category': 'storage'}
# Entity:
# {'entity': 'Pod A-1', 'description': '', 'category': 'container'}
# Entity:
# {'entity': 'PVC A-2', 'description': '', 'category': 'database'}
# Entity:
# {'entity': 'PV', 'description': '', 'category': 'storage'}
# Entity:
# {'entity': 'Pod A-2', 'description': '', 'category': 'container'}
# Done for page 231
# Page Number
# 232
# Page Entity List Dictionary Cleaned
# [
#   {"entity": "StatefulSet", "description": "A Kubernetes concept for managing stateful applications.", "category": "software"},
#   {"entity": "PersistentVolumeClaim", "description": "A request for storage resources in a Kubernetes cluster.", "category": "software"},
#   {"entity": "Pod", "description": "The basic execution unit of a Kubernetes application.", "category": "software"},
#   {"entity": "ReplicaSet", "description": "A Kubernetes concept for managing multiple replicas of an application.", "category": "software"},
#   {"entity": "Replication-Controller", "description": "An older Kubernetes concept for managing multiple replicas of an application.", "category": "software"},
#   {"entity": "Kubernetes", "description": "An open-source container orchestration system.", "category": "software"},
#   {"entity": "PersistentVolume", "description": "A storage resource in a Kubernetes cluster that can be claimed by a PersistentVolumeClaim.", "category": "hardware"},
#   {"entity": "scale-down", "description": "The process of reducing the number of replicas of an application in a Kubernetes cluster.", "category": "process"},
#   {"entity": "scale-up", "description": "The process of increasing the number of replicas of an application in a Kubernetes cluster.", "category": "process"},
#   {"entity": "StatefulSet guarantees", "description": "The set of assurances provided by StatefulSets regarding the behavior of their pods.", "category": "software"}
# ]
# Entity:
# {'entity': 'StatefulSet', 'description': 'A Kubernetes concept for managing stateful applications.', 'category': 'software'}
# Entity:
# {'entity': 'PersistentVolumeClaim', 'description': 'A request for storage resources in a Kubernetes cluster.', 'category': 'software'}
# Entity:
# {'entity': 'Pod', 'description': 'The basic execution unit of a Kubernetes application.', 'category': 'software'}
# Entity:
# {'entity': 'ReplicaSet', 'description': 'A Kubernetes concept for managing multiple replicas of an application.', 'category': 'software'}
# Entity:
# {'entity': 'Replication-Controller', 'description': 'An older Kubernetes concept for managing multiple replicas of an application.', 'category': 'software'}
# Entity:
# {'entity': 'Kubernetes', 'description': 'An open-source container orchestration system.', 'category': 'software'}
# Entity:
# {'entity': 'PersistentVolume', 'description': 'A storage resource in a Kubernetes cluster that can be claimed by a PersistentVolumeClaim.', 'category': 'hardware'}
# Entity:
# {'entity': 'scale-down', 'description': 'The process of reducing the number of replicas of an application in a Kubernetes cluster.', 'category': 'process'}
# Entity:
# {'entity': 'scale-up', 'description': 'The process of increasing the number of replicas of an application in a Kubernetes cluster.', 'category': 'process'}
# Entity:
# {'entity': 'StatefulSet guarantees', 'description': 'The set of assurances provided by StatefulSets regarding the behavior of their pods.', 'category': 'software'}
# Done for page 232
# Page Number
# 233
# Page Entity List Dictionary Cleaned
# [
#   {"entity": "StatefulSets", "description": "a Kubernetes resource for deploying replicated stateful applications", "category": "application"},
#   {"entity": "ReplicaSet", "description": "a Kubernetes resource for managing a set of replicas", "category": "application"},
#   {"entity": "pods", "description": "managed by a ReplicaSet", "category": "container"},
#   {"entity": "PersistentVolumeClaim", "description": "a request for storage resources", "category": "database"},
#   {"entity": "StatefulSet", "description": "must guarantee at-most-one semantics for stateful pod instances", "category": "application"},
#   {"entity": "pod", "description": "instance of a container running in a Kubernetes cluster", "category": "container"},
#   {"entity": "kubia app", "description": "a simple web application used as an example throughout the book", "category": "application"},
#   {"entity": "data store", "description": "a clustered data store built using StatefulSets", "category": "database"},
#   {"entity": "container image", "description": "the base image for a container running in a Kubernetes cluster", "category": "container"},
#   {"entity": "fs.createWriteStream", "description": "a function for creating a write stream to a file", "category": "process"},
#   {"entity": "request.pipe", "description": "a method for piping data from one stream to another", "category": "process"},
#   {"entity": "console.log", "description": "a function for logging messages to the console", "category": "process"},
#   {"entity": "response.writeHead", "description": "a method for setting HTTP headers on a response object", "category": "process"},
#   {"entity": "response.end", "description": "a method for ending an HTTP response", "category": "process"},
#   {"entity": "fileExists", "description": "a function for checking if a file exists", "category": "process"},
#   {"entity": "fs.readFileSync", "description": "a function for reading the contents of a file synchronously", "category": "process"}
# ]
# Entity:
# {'entity': 'StatefulSets', 'description': 'a Kubernetes resource for deploying replicated stateful applications', 'category': 'application'}
# Entity:
# {'entity': 'ReplicaSet', 'description': 'a Kubernetes resource for managing a set of replicas', 'category': 'application'}
# Entity:
# {'entity': 'pods', 'description': 'managed by a ReplicaSet', 'category': 'container'}
# Entity:
# {'entity': 'PersistentVolumeClaim', 'description': 'a request for storage resources', 'category': 'database'}
# Entity:
# {'entity': 'StatefulSet', 'description': 'must guarantee at-most-one semantics for stateful pod instances', 'category': 'application'}
# Entity:
# {'entity': 'pod', 'description': 'instance of a container running in a Kubernetes cluster', 'category': 'container'}
# Entity:
# {'entity': 'kubia app', 'description': 'a simple web application used as an example throughout the book', 'category': 'application'}
# Entity:
# {'entity': 'data store', 'description': 'a clustered data store built using StatefulSets', 'category': 'database'}
# Entity:
# {'entity': 'container image', 'description': 'the base image for a container running in a Kubernetes cluster', 'category': 'container'}
# Entity:
# {'entity': 'fs.createWriteStream', 'description': 'a function for creating a write stream to a file', 'category': 'process'}
# Entity:
# {'entity': 'request.pipe', 'description': 'a method for piping data from one stream to another', 'category': 'process'}
# Entity:
# {'entity': 'console.log', 'description': 'a function for logging messages to the console', 'category': 'process'}
# Entity:
# {'entity': 'response.writeHead', 'description': 'a method for setting HTTP headers on a response object', 'category': 'process'}
# Entity:
# {'entity': 'response.end', 'description': 'a method for ending an HTTP response', 'category': 'process'}
# Entity:
# {'entity': 'fileExists', 'description': 'a function for checking if a file exists', 'category': 'process'}
# Entity:
# {'entity': 'fs.readFileSync', 'description': 'a function for reading the contents of a file synchronously', 'category': 'process'}
# Done for page 233
# Page Number
# 234
# Page Entity List Dictionary Cleaned
# [
#   {"entity": "StatefulSet", "description": "", "category": "software"},
#   {"entity": "http.createServer(handler)", "description": "", "category": "command"},
#   {"entity": "listen(8080)", "description": "", "category": "command"},
#   {"entity": "/var/data/kubia.txt", "description": "file path", "category": "hardware"},
#   {"entity": "POST request", "description": "HTTP request method", "category": "software"},
#   {"entity": "GET request", "description": "HTTP request method", "category": "software"},
#   {"entity": "Dockerfile", "description": "", "category": "software"},
#   {"entity": "node:7", "description": "Docker image tag", "category": "hardware"},
#   {"entity": "app.js", "description": "JavaScript file", "category": "software"},
#   {"entity": "ENTRYPOINT", "description": "Docker command", "category": "command"},
#   {"entity": "PersistentVolumes", "description": "", "category": "hardware"},
#   {"entity": "PersistentVolumeClaim", "description": "", "category": "hardware"},
#   {"entity": "Service", "description": "", "category": "software"},
#   {"entity": "StatefulSet", "description": "", "category": "software"},
#   {"entity": "PersistentVolumes", "description": "", "category": "hardware"},
#   {"entity": "Minikube", "description": "", "category": "software"},
#   {"entity": "Google Kubernetes Engine", "description": "", "category": "software"},
#   {"entity": "$ gcloud compute disks create", "description": "command", "category": "command"},
#   {"entity": "--size=1GiB", "description": "disk size option", "category": "hardware"},
#   {"entity": "--zone=europe-west1-b", "description": "disk zone option", "category": "hardware"},
#   {"entity": "pv-a", "description": "persistent disk name", "category": "hardware"},
#   {"entity": "pv-b", "description": "persistent disk name", "category": "hardware"},
#   {"entity": "pv-c", "description": "persistent disk name", "category": "hardware"}
# ]
# Entity:
# {'entity': 'StatefulSet', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'http.createServer(handler)', 'description': '', 'category': 'command'}
# Entity:
# {'entity': 'listen(8080)', 'description': '', 'category': 'command'}
# Entity:
# {'entity': '/var/data/kubia.txt', 'description': 'file path', 'category': 'hardware'}
# Entity:
# {'entity': 'POST request', 'description': 'HTTP request method', 'category': 'software'}
# Entity:
# {'entity': 'GET request', 'description': 'HTTP request method', 'category': 'software'}
# Entity:
# {'entity': 'Dockerfile', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'node:7', 'description': 'Docker image tag', 'category': 'hardware'}
# Entity:
# {'entity': 'app.js', 'description': 'JavaScript file', 'category': 'software'}
# Entity:
# {'entity': 'ENTRYPOINT', 'description': 'Docker command', 'category': 'command'}
# Entity:
# {'entity': 'PersistentVolumes', 'description': '', 'category': 'hardware'}
# Entity:
# {'entity': 'PersistentVolumeClaim', 'description': '', 'category': 'hardware'}
# Entity:
# {'entity': 'Service', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'StatefulSet', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'PersistentVolumes', 'description': '', 'category': 'hardware'}
# Entity:
# {'entity': 'Minikube', 'description': '', 'category': 'software'}
# Entity:
# {'entity': 'Google Kubernetes Engine', 'description': '', 'category': 'software'}
# Entity:
# {'entity': '$ gcloud compute disks create', 'description': 'command', 'category': 'command'}
# Entity:
# {'entity': '--size=1GiB', 'description': 'disk size option', 'category': 'hardware'}
# Entity:
# {'entity': '--zone=europe-west1-b', 'description': 'disk zone option', 'category': 'hardware'}
# Entity:
# {'entity': 'pv-a', 'description': 'persistent disk name', 'category': 'hardware'}
# Entity:
# {'entity': 'pv-b', 'description': 'persistent disk name', 'category': 'hardware'}
# Entity:
# {'entity': 'pv-c', 'description': 'persistent disk name', 'category': 'hardware'}
# Done for page 234
# Page Number
# 235
# Page Entity List Dictionary Cleaned
# [
#   {"entity": "StatefulSets", "description": "deploying replicated stateful applications", "category": "application"},
#   {"entity": "PersistentVolumes", "description": "from the persistent-volumes-gcepd.yaml file", "category": "database"},
#   {"entity": "List", "description": "object and listing the resources as items of the object", "category": "framework"},
#   {"entity": "apiVersion", "description": "version of the API", "category": "software"},
#   {"entity": "kind", "description": "type of resource", "category": "software"},
#   {"entity": "metadata", "description": "information about the resource", "category": "database"},
#   {"entity": "name", "description": "name of the PersistentVolume", "category": "database"},
#   {"entity": "capacity", "description": "storage capacity of each persistent volume", "category": "hardware"},
#   {"entity": "storage", "description": "amount of storage available", "category": "hardware"},
#   {"entity": "ReadWriteOnce", "description": "access mode for the PersistentVolume", "category": "database"},
#   {"entity": "Recycle", "description": "policy for reclaiming the PersistentVolume", "category": "process"},
#   {"entity": "gcePersistentDisk", "description": "underlying storage mechanism for the PersistentVolume", "category": "hardware"},
#   {"entity": "pdName", "description": "name of the GCE Persistent Disk", "category": "database"},
#   {"entity": "fsType", "description": "file system type used by the PersistentVolume", "category": "software"},
#   {"entity": "nfs4", "description": "file system type used by the PersistentVolume", "category": "software"},
#   {"entity": "PersistentVolumeReclaimPolicy", "description": "policy for reclaiming the PersistentVolume", "category": "process"},
#   {"entity": "Service", "description": "headless Service to provide network identity for stateful pods", "category": "application"},
#   {"entity": "clusterIP", "description": "IP address of the Service", "category": "network"},
#   {"entity": "None", "description": "value indicating that the Service is headless", "category": "software"}
# ]
# Entity:
# {'entity': 'StatefulSets', 'description': 'deploying replicated stateful applications', 'category': 'application'}
# Entity:
# {'entity': 'PersistentVolumes', 'description': 'from the persistent-volumes-gcepd.yaml file', 'category': 'database'}
# Entity:
# {'entity': 'List', 'description': 'object and listing the resources as items of the object', 'category': 'framework'}
# Entity:
# {'entity': 'apiVersion', 'description': 'version of the API', 'category': 'software'}
# Entity:
# {'entity': 'kind', 'description': 'type of resource', 'category': 'software'}
# Entity:
# {'entity': 'metadata', 'description': 'information about the resource', 'category': 'database'}
# Entity:
# {'entity': 'name', 'description': 'name of the PersistentVolume', 'category': 'database'}
# Entity:
# {'entity': 'capacity', 'description': 'storage capacity of each persistent volume', 'category': 'hardware'}
# Entity:
# {'entity': 'storage', 'description': 'amount of storage available', 'category': 'hardware'}
# Entity:
# {'entity': 'ReadWriteOnce', 'description': 'access mode for the PersistentVolume', 'category': 'database'}
# Entity:
# ...
#   {"entity": "curl", "description": "the command-line tool for making HTTP requests", "category": "command"},
#   {"entity": "api/v1/namespaces/foo/pods", "description": "the API endpoint for listing pods in the foo namespace", "category": "application"}
# ]
# Entity:
# {'entity': 'pod', 'description': 'a container running an application', 'category': 'container'}
# Entity:
# {'entity': 'ClusterRoleBinding', 'description': 'a binding between a ClusterRole and a user or service account', 'category': 'database'}
# Entity:
# {'entity': 'ClusterRole', 'description': 'a set of permissions for accessing cluster-level resources', 'category': 'database'}
# Entity:
# {'entity': 'RoleBinding', 'description': 'a binding between a Role and a user or service account', 'category': 'database'}
# Entity:
# {'entity': 'ServiceAccount', 'description': 'an identity for an application running in a pod', 'category': 'application'}
# Entity:
# {'entity': 'namespace', 'description': 'a logical grouping of resources within a cluster', 'category': 'network'}
# Entity:
# {'entity': 'Role', 'description': 'a set of permissions for accessing namespaced resources', 'category': 'database'}
# Entity:
# {'entity': 'kubectl', 'description': 'the command-line tool for interacting with a Kubernetes cluster', 'category': 'command'}
# Entity:
# {'entity': 'curl', 'description': 'the command-line tool for making HTTP requests', 'category': 'command'}
# Entity:
# {'entity': 'api/v1/namespaces/foo/pods', 'description': 'the API endpoint for listing pods in the foo namespace', 'category': 'application'}
# Done for page 312
# Page Number
# 313
# Page Entity List Dictionary Cleaned
# [
#   {"entity": "Kubernetes API server", "description": "", "category": "application"},
#   {"entity": "curl", "description": "command-line tool for transferring data to and from a web server", "category": "software"},
#   {"entity": "localhost:8001/api/v1/namespaces/bar/pods", "description": "API endpoint for listing pods in namespace bar", "category": "application"},
#   {"entity": "User system:serviceaccount:foo:default", "description": "", "category": "user"},
#   {"entity": "pods", "description": "Kubernetes resources representing running containers", "category": "resource"},
#   {"entity": "namespaces", "description": "Kubernetes resources representing logical partitions of a cluster", "category": "resource"},
#   {"entity": "ClusterRole", "description": "Kubernetes resource type for defining permissions at the cluster level", "category": "resource"},
#   {"entity": "ClusterRoleBinding", "description": "Kubernetes resource type for binding a ClusterRole to a user or service account", "category": "resource"},
#   {"entity": "Role", "description": "Kubernetes resource type for defining permissions at the namespace level", "category": "resource"},
#   {"entity": "RoleBinding", "description": "Kubernetes resource type for binding a Role to a user or service account", "category": "resource"},
#   {"entity": "ServiceAccount", "description": "Kubernetes resource type representing an identity for a pod or container", "category": "resource"},
#   {"entity": "default ServiceAccount", "description": "", "category": "user"}
# ]
# Entity:
# {'entity': 'Kubernetes API server', 'description': '', 'category': 'application'}
# Entity:
# {'entity': 'curl', 'description': 'command-line tool for transferring data to and from a web server', 'category': 'software'}
# Entity:
# {'entity': 'localhost:8001/api/v1/namespaces/bar/pods', 'description': 'API endpoint for listing pods in namespace bar', 'category': 'application'}
# Entity:
# {'entity': 'User system:serviceaccount:foo:default', 'description': '', 'category': 'user'}
# Entity:
# {'entity': 'pods', 'description': 'Kubernetes resources representing running containers', 'category': 'resource'}
# Entity:
# {'entity': 'namespaces', 'description': 'Kubernetes resources representing logical partitions of a cluster', 'category': 'resource'}
# Entity:
# {'entity': 'ClusterRole', 'description': 'Kubernetes resource type for defining permissions at the cluster level', 'category': 'resource'}
# Entity:
# {'entity': 'ClusterRoleBinding', 'description': 'Kubernetes resource type for binding a ClusterRole to a user or service account', 'category': 'resource'}
# Entity:
# {'entity': 'Role', 'description': 'Kubernetes resource type for defining permissions at the namespace level', 'category': 'resource'}
# Entity:
# {'entity': 'RoleBinding', 'description': 'Kubernetes resource type for binding a Role to a user or service account', 'category': 'resource'}
# Entity:
# {'entity': 'ServiceAccount', 'description': 'Kubernetes resource type representing an identity for a pod or container', 'category': 'resource'}
# Entity:
# {'entity': 'default ServiceAccount', 'description': '', 'category': 'user'}
# Done for page 313
# Page Number
# 314
# Page Entity List Dictionary Cleaned
# [
#   {"entity": "role-based access control", "description": "", "category": "process"},
#   {"entity": "ClusterRoles", "description": "", "category": "database"},
#   {"entity": "ClusterRoleBindings", "description": "", "category": "database"},
#   {"entity": "kubectl", "description": "command-line interface for Kubernetes", "category": "software"},
#   {"entity": "cluster-admin", "description": "", "category": "process"},
#   {"entity": "system:basic-user", "description": "", "category": "process"},
#   {"entity": "system:controller:attachdetach-controller", "description": "", "category": "process"},
#   {"entity": "system:discovery", "description": "", "category": "process"},
#   {"entity": "system:kube-controller-manager", "description": "", "category": "process"},
#   {"entity": "system:kube-dns", "description": "", "category": "process"},
#   {"entity": "system:kube-scheduler", "description": "", "category": "process"},
#   {"entity": "system:node", "description": "", "category": "process"},
#   {"entity": "system:node-proxier", "description": "", "category": "process"},
#   {"entity": "admin", "description": "", "category": "process"},
#   {"entity": "cluster-admin", "description": "", "category": "process"},
#   {"entity": "edit", "description": "", "category": "process"},
#   {"entity": "system:auth-delegator", "description": "", "category": "process"},
#   {"entity": "system:basic-user", "description": "", "category": "process"},
#   {"entity": "system:controller:attachdetach-controller", "description": "", "category": "process"},
#   {"entity": "system:discovery", "description": "", "category": "process"},
#   {"entity": "system:heapster", "description": "", "category": "process"},
#   {"entity": "system:kube-aggregator", "description": "", "category": "process"},
#   {"entity": "system:kube-controller-manager", "description": "", "category": "process"},
#   {"entity": "system:kube-dns", "description": "", "category": "process"},
#   {"entity": "system:kube-scheduler", "description": "", "category": "process"},
#   {"entity": "system:node", "description": "", "category": "process"},
#   {"entity": "system:node-bootstrapper", "description": "", "category": "process"},
#   {"entity": "system:node-problem-detector", "description": "", "category": "process"},
#   {"entity": "system:node-proxier", "description": "", "category": "process"},
#   {"entity": "system:persistent-volume-provisioner", "description": "", "category": "process"},
#   {"entity": "view", "description": "", "category": "process"}
# ]
# Entity:
# {'entity': 'role-based access control', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'ClusterRoles', 'description': '', 'category': 'database'}
# Entity:
# {'entity': 'ClusterRoleBindings', 'description': '', 'category': 'database'}
# Entity:
# {'entity': 'kubectl', 'description': 'command-line interface for Kubernetes', 'category': 'software'}
# Entity:
# {'entity': 'cluster-admin', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:basic-user', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:controller:attachdetach-controller', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:discovery', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:kube-controller-manager', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:kube-dns', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:kube-scheduler', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:node', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:node-proxier', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'admin', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'cluster-admin', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'edit', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:auth-delegator', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:basic-user', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:controller:attachdetach-controller', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:discovery', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:heapster', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:kube-aggregator', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:kube-controller-manager', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:kube-dns', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:kube-scheduler', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:node', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:node-bootstrapper', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:node-problem-detector', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:node-proxier', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'system:persistent-volume-provisioner', 'description': '', 'category': 'process'}
# Entity:
# {'entity': 'view', 'description': '', 'category': 'process'}
# Done for page 314
# Page Number
# 315
# Page Entity List Dictionary Cleaned
# [
#   {"entity": "Kubernetes API server", "description": "The most important roles are the view, edit, admin, and cluster-admin ClusterRoles.", "category": "software"},
#   {"entity": "ClusterRoles", "description": "They’re meant to be bound to ServiceAccounts used by user-defined pods.", "category": "software"},
#   {"entity": "view ClusterRole", "description": "It allows read-ing most resources in a namespace, except for Roles, RoleBindings, and Secrets.", "category": "software"},
#   {"entity": "Roles", "description": "You’re probably wondering, why not Secrets? Because one of those Secrets might include an authentication token with greater privileges than those defined in the view Cluster-Role and could allow the user to masquerade as a different user to gain additional privileges (privilege escalation).", "category": "software"},
#   {"entity": "Secrets", "description": "It doesn’t, however, allow viewing or modifying Roles or RoleBindings—again, this is to prevent privilege escalation.", "category": "software"},
#   {"entity": "edit ClusterRole", "description": "Next is the edit ClusterRole, which allows you to modify resources in a namespace, but also allows both reading and modifying Secrets.", "category": "software"},
#   {"entity": "admin ClusterRole", "description": "Complete control of the resources in a namespace is granted in the admin Cluster-Role. Subjects with this ClusterRole can read and modify any resource in the name-space, except ResourceQuotas (we’ll learn what those are in chapter 14) and the Namespace resource itself.", "category": "software"},
#   {"entity": "ResourceQuotas", "description": "The main difference between the edit and the admin Cluster-Roles is in the ability to view and modify Roles and RoleBindings in the namespace.", "category": "software"},
#   {"entity": "Namespace", "description": "To prevent privilege escalation, the API server only allows users to create and update Roles if they already have all the permissions listed in that Role (and for the same scope).", "category": "software"},
#   {"entity": "cluster-admin ClusterRole", "description": "Complete control of the Kubernetes cluster can be given by assigning the cluster-admin ClusterRole to a subject.", "category": "software"},
#   {"view", "description": "ALLOWING READ-ONLY ACCESS TO RESOURCES WITH THE VIEW CLUSTERROLE", "category": "software"},
#   {"edit", "description": "ALLOWING MODIFYING RESOURCES WITH THE EDIT CLUSTERROLE", "category": "software"},
#   {"admin", "description": "GRANTING FULL CONTROL OF A NAMESPACE WITH THE ADMIN CLUSTERROLE", "category": "software"},
#   {"cluster-admin", "description": "ALLOWING COMPLETE CONTROL WITH THE CLUSTER-ADMIN CLUSTERROLE ", "category": "software"},
#   {"RoleBinding", "description": "If you want to allow a user to do that, you need to create a RoleBinding that references the cluster-admin ClusterRole.", "category": "software"},
#   {"ClusterRoleBinding", "description": "This gives the user included in the RoleBinding complete control over all aspects of the namespace in which the Role-Binding is created.", "category": "software"},
#   {"ServiceAccounts", "description": "They’re meant to be bound to ServiceAccounts used by user-defined pods.", "category": "software"},
#   {"Roles", "description": "You already know how to give users complete control of all the namespaces in the cluster. Yes, by referencing the cluster-admin ClusterRole in a ClusterRoleBinding instead of a RoleBinding.", "category": "software"},
#   {"Kubelets", "description": "Among them, you’ll find roles such as system:kube-scheduler, which is obviously used by the Scheduler, system:node, which is used by the Kubelets, and so on. ", "category": "software"}
# ]
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[10], line 3
#       1 for idx in range(start_page_idx,end_page_index):
# ----> 3         enrich_page(idx)
#
# Cell In[9], line 30, in enrich_page(page_idx)
#      27 print("Page Entity List Dictionary Cleaned")
#      28 print(page_entity_lst_dict)
# ---> 30 page_entity_lst_json=json.loads(page_entity_lst_dict)
#      31 document_dict_deserialized[page_idx]['entities']=page_entity_lst_json
#      33 ##Collate entity list per page into unique Entities
#
# File ~/mambaforge-pypy3/envs/search_agent_poc/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/mambaforge-pypy3/envs/search_agent_poc/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/mambaforge-pypy3/envs/search_agent_poc/lib/python3.10/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ':' delimiter: line 12 column 10 (char 2255)

# %%
document_dict_deserialized[467]
# Out:
# {'page': 556,
#  'img_cnt': 0,
#  'img_flag': 0,
#  'img_npy_lst': [],
#  'text': '524\nCHAPTER 18\nExtending Kubernetes\n18.2.4 Provisioning and using a service\nLet’s imagine the pods you’re deploying need to use a database. You’ve inspected the\nlist of available ClusterServiceClasses and have chosen to use the free plan of the\npostgres-database ClusterServiceClass. \nPROVISIONING A SERVICEINSTANCE\nTo have the database provisioned for you, all you need to do is create a Service-\nInstance resource, as shown in the following listing.\napiVersion: servicecatalog.k8s.io/v1alpha1\nkind: ServiceInstance\nmetadata:\n  name: my-postgres-db                     \nspec:\n  clusterServiceClassName: postgres-database        \n  clusterServicePlanName: free                             \n  parameters:\n    init-db-args: --data-checksums         \nYou created a ServiceInstance called my-postgres-db (that will be the name of the\nresource you’re deploying) and specified the ClusterServiceClass and the chosen\nplan. You’re also specifying a parameter, which is specific for each broker and Cluster-\nServiceClass. Let’s imagine you looked up the possible parameters in the broker’s doc-\numentation.\n As soon as you create this resource, the Service Catalog will contact the broker the\nClusterServiceClass belongs to and ask it to provision the service. It will pass on the\nchosen ClusterServiceClass and plan names, as well as all the parameters you specified.\n It’s then completely up to the broker to know what to do with this information. In\nyour case, your database broker will probably spin up a new instance of a PostgreSQL\ndatabase somewhere—not necessarily in the same Kubernetes cluster or even in\nKubernetes at all. It could run a Virtual Machine and run the database in there. The\nService Catalog doesn’t care, and neither does the user requesting the service. \n You can check if the service has been provisioned successfully by inspecting the\nstatus section of the my-postgres-db ServiceInstance you created, as shown in the\nfollowing listing.\n$ kubectl get instance my-postgres-db -o yaml\napiVersion: servicecatalog.k8s.io/v1alpha1\nkind: ServiceInstance\n...\nstatus:\n  asyncOpInProgress: false\n  conditions:\nListing 18.12\nA ServiceInstance manifest: database-instance.yaml\nListing 18.13\nInspecting the status of a ServiceInstance\nYou’re giving this \nInstance a name.\nThe ServiceClass \nand Plan you want\nAdditional parameters \npassed to the broker\n \n',
#  'tables_flag': 0,
#  'tables': [],
#  'entities': [{'entity': 'Kubernetes',
#    'description': 'Container orchestration system',
#    'category': 'software'},
#   {'entity': 'Service Catalog',
#    'description': 'API for provisioning and managing services',
#    'category': 'software'},
#   {'entity': 'ClusterServiceClass',
#    'description': 'Template for a service instance',
#    'category': 'software'},
#   {'entity': 'postgres-database',
#    'description': 'ClusterServiceClass for PostgreSQL database',
#    'category': 'software'},
#   {'entity': 'ServiceInstance',
#    'description': 'Resource representing a provisioned service',
#    'category': 'software'},
#   {'entity': 'parameters',
#    'description': 'Additional data passed to the broker during provisioning',
#    'category': 'process'},
#   {'entity': 'init-db-args',
#    'description': 'Parameter for initializing database',
#    'category': 'parameter'},
#   {'entity': 'kubectl',
#    'description': 'Command-line tool for interacting with Kubernetes',
#    'category': 'command'},
#   {'entity': 'get instance',
#    'description': 'Command for retrieving information about a service instance',
#    'category': 'command'},
#   {'entity': 'yaml',
#    'description': 'Format for outputting data in human-readable format',
#    'category': 'format'},
#   {'entity': 'apiVersion',
#    'description': 'Field specifying the API version of a resource',
#    'category': 'field'},
#   {'entity': 'kind',
#    'description': 'Field specifying the type of a resource',
#    'category': 'field'},
#   {'entity': 'metadata',
#    'description': 'Field containing metadata about a resource',
#    'category': 'field'},
#   {'entity': 'name',
#    'description': 'Field specifying the name of a resource',
#    'category': 'field'},
#   {'entity': 'spec',
#    'description': 'Field specifying the specification of a service instance',
#    'category': 'field'},
#   {'entity': 'clusterServiceClassName',
#    'description': 'Field specifying the ClusterServiceClass for a service instance',
#    'category': 'field'},
#   {'entity': 'clusterServicePlanName',
#    'description': 'Field specifying the plan for a service instance',
#    'category': 'field'},
#   {'entity': 'parameters',
#    'description': 'Field containing additional parameters for a service instance',
#    'category': 'field'}],
#  'relationships': '[{"source_entity": "You", "description": "create a ServiceInstance resource", "destination_entity": "my-postgres-db"},\n {"source_entity": "You", "description": "specify the ClusterServiceClass and chosen plan", "destination_entity": "postgres-database"},\n {"source_entity": "You", "description": "specify a parameter", "destination_entity": "init-db-args"},\n {"source_entity": "The Service Catalog", "description": "contact the broker to provision the service", "destination_entity": "the ClusterServiceClass"},\n {"source_entity": "The Service Catalog", "description": "pass on the chosen ClusterServiceClass and plan names, as well as all parameters", "destination_entity": "the broker"},\n {"source_entity": "The broker", "description": "know what to do with the information", "destination_entity": "the ServiceInstance"},\n {"source_entity": "Your database broker", "description": "spin up a new instance of a PostgreSQL database", "destination_entity": "a Virtual Machine"},\n {"source_entity": "You", "description": "check if the service has been provisioned successfully", "destination_entity": "the status section of the my-postgres-db ServiceInstance"},\n {"source_entity": "kubectl", "description": "get the instance", "destination_entity": "my-postgres-db"}]',
#  'summary': 'To use a service like a database in Kubernetes, create a Service-Instance resource specifying the ClusterServiceClass and chosen plan, along with any required parameters. The Service Catalog will then provision the service by contacting the broker, which may spin up a new instance of the database in a VM or elsewhere. Successful provisioning can be checked by inspecting the status section of the ServiceInstance.',
#  'highlights': [{'highlight': 'To have the database provisioned for you, all you need to do is create a Service-Instance resource, as shown in the following listing.'},
#   {'highlight': 'The Service Catalog will contact the broker the ClusterServiceClass belongs to and ask it to provision the service. It will pass on the chosen ClusterServiceClass and plan names, as well as all the parameters you specified.'},
#   {'highlight': 'You can check if the service has been provisioned successfully by inspecting the status section of the my-postgres-db ServiceInstance you created, as shown in the following listing.'},
#   {'highlight': 'A ServiceInstance manifest: database-instance.yaml'},
#   {'highlight': 'The Service Catalog doesn’t care, and neither does the user requesting the service. The broker is responsible for provisioning the service according to the provided parameters.'}]}

# %%
import pickle

# Store data (serialize in a pickle) upto page 102
with open('./pdf_enriched_output/pdf_enriched_content_dict_phase1_entity_extraction_314.pickle', 'wb') as handle:
    pickle.dump(document_dict_deserialized, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
document_dict_deserialized[155]
# Out:
# {'page': 244,
#  'img_cnt': 0,
#  'img_flag': 0,
#  'img_npy_lst': [],
#  'text': '212\nCHAPTER 7\nConfigMaps and Secrets: configuring applications\nEDITING A CONFIGMAP\nLet’s see how you can change a ConfigMap and have the process running in the pod\nreload the files exposed in the configMap volume. You’ll modify the Nginx config file\nfrom your previous example and make Nginx use the new config without restarting\nthe pod. Try switching gzip compression off by editing the fortune-config Config-\nMap with kubectl edit:\n$ kubectl edit configmap fortune-config\nOnce your editor opens, change the gzip on line to gzip off, save the file, and then\nclose the editor. The ConfigMap is then updated, and soon afterward, the actual file\nin the volume is updated as well. You can confirm this by printing the contents of the\nfile with kubectl exec:\n$ kubectl exec fortune-configmap-volume -c web-server\n➥  cat /etc/nginx/conf.d/my-nginx-config.conf\nIf you don’t see the update yet, wait a while and try again. It takes a while for the\nfiles to get updated. Eventually, you’ll see the change in the config file, but you’ll\nfind this has no effect on Nginx, because it doesn’t watch the files and reload them\nautomatically. \nSIGNALING NGINX TO RELOAD THE CONFIG\nNginx will continue to compress its responses until you tell it to reload its config files,\nwhich you can do with the following command:\n$ kubectl exec fortune-configmap-volume -c web-server -- nginx -s reload\nNow, if you try hitting the server again with curl, you should see the response is no\nlonger compressed (it no longer contains the Content-Encoding: gzip header).\nYou’ve effectively changed the app’s config without having to restart the container or\nrecreate the pod. \nUNDERSTANDING HOW THE FILES ARE UPDATED ATOMICALLY\nYou may wonder what happens if an app can detect config file changes on its own and\nreloads them before Kubernetes has finished updating all the files in the configMap\nvolume. Luckily, this can’t happen, because all the files are updated atomically, which\nmeans all updates occur at once. Kubernetes achieves this by using symbolic links. If\nyou list all the files in the mounted configMap volume, you’ll see something like the\nfollowing listing.\n$ kubectl exec -it fortune-configmap-volume -c web-server -- ls -lA \n➥  /etc/nginx/conf.d\ntotal 4\ndrwxr-xr-x  ... 12:15 ..4984_09_04_12_15_06.865837643\nListing 7.19\nFiles in a mounted configMap volume\n \n',
#  'tables_flag': 0,
#  'tables': [],
#  'entities': [{'entity': 'ConfigMaps',
#    'description': 'A feature in Kubernetes that allows you to store and manage configuration data as key-value pairs.',
#    'category': 'software'},
#   {'entity': 'kubectl edit',
#    'description': 'A command used to edit a ConfigMap or other Kubernetes resource directly from the terminal.',
#    'category': 'command'},
#   {'entity': 'fortune-config Config-Map',
#    'description': 'A specific ConfigMap used in the example to store configuration data for an Nginx server.',
#    'category': 'software'},
#   {'entity': 'gzip compression',
#    'description': 'A feature of Nginx that compresses responses to reduce bandwidth usage.',
#    'category': 'process'},
#   {'entity': 'Nginx config file',
#    'description': 'A configuration file used by the Nginx server to determine how to handle requests.',
#    'category': 'file'},
#   {'entity': 'kubectl exec',
#    'description': 'A command used to execute a command inside a running container or pod.',
#    'category': 'command'},
#   {'entity': 'nginx -s reload',
#    'description': 'A command used to signal the Nginx server to reload its configuration files.',
#    'category': 'command'},
#   {'entity': 'ConfigMap volume',
#    'description': 'A directory in a pod that is mounted from a ConfigMap, containing configuration data for an application.',
#    'category': 'directory'},
#   {'entity': 'symbolic links',
#    'description': 'A feature used by Kubernetes to update files in a ConfigMap volume atomically.',
#    'category': 'process'},
#   {'entity': 'kubectl exec -it',
#    'description': 'A command used to execute a command inside a running container or pod, with interactive shell.',
#    'category': 'command'}],
#  'relationships': '[\n  {\n    "source_entity": "kubectl edit",\n    "description": "edit a ConfigMap and have the process running in the pod reload the files exposed in the configMap volume",\n    "destination_entity": "ConfigMap"\n  },\n  {\n    "source_entity": "fortune-config Config-Map",\n    "description": "update the gzip compression setting to \'gzip off\'",\n    "destination_entity": "Nginx config file"\n  },\n  {\n    "source_entity": "kubectl exec",\n    "description": "print the contents of a file in the volume",\n    "destination_entity": "/etc/nginx/conf.d/my-nginx-config.conf"\n  },\n  {\n    "source_entity": "nginx -s reload",\n    "description": "reload Nginx config files and update the app\'s config without restarting the container or recreating the pod",\n    "destination_entity": "Nginx"\n  },\n  {\n    "source_entity": "kubectl exec",\n    "description": "execute a command in a container to reload Nginx config files",\n    "destination_entity": "fortune-config Config-Map volume"\n  },\n  {\n    "source_entity": "ConfigMaps",\n    "description": "configure applications using ConfigMaps and Secrets",\n    "destination_entity": "applications"\n  },\n  {\n    "source_entity": "kubectl exec",\n    "description": "execute a command in a container to list files in the mounted configMap volume",\n    "destination_entity": "/etc/nginx/conf.d"\n  },\n  {\n    "source_entity": "symbolic links",\n    "description": "achieve atomic updates of all files in the configMap volume using symbolic links",\n    "destination_entity": "ConfigMaps"\n  },\n  {\n    "source_entity": "gzip compression",\n    "description": "update the gzip compression setting to \'gzip off\' and observe its effect on Nginx responses",\n    "destination_entity": "Nginx responses"\n  }\n]',
#  'summary': 'A ConfigMap can be edited using kubectl edit to change its contents, and the changes will propagate to the actual file in the volume. However, the application may not automatically reload the updated files. To force Nginx to reload its config files, use the command `nginx -s reload`. Kubernetes achieves atomic updates by using symbolic links.',
#  'highlights': [{'highlight': 'You can change a ConfigMap and have the process running in the pod reload the files exposed in the configMap volume by editing the Nginx config file with kubectl edit.'},
#   {'highlight': 'To signal Nginx to reload its config files, you can use the command $ kubectl exec fortune-configmap-volume -c web-server -- nginx -s reload'},
#   {'highlight': 'All the files in a mounted configMap volume are updated atomically, which means all updates occur at once, thanks to Kubernetes using symbolic links.'},
#   {'highlight': 'You can confirm that the ConfigMap has been updated by printing the contents of the file with kubectl exec and checking for changes in the config file.'},
#   {'highlight': 'Editing a ConfigMap does not require restarting the container or recreating the pod, as the changes are applied atomically and Nginx will reload its config files automatically.'}]}

# %%
####The main contents of Kubernets In Action book is contained from page 87 to 565####
####Thats why we will only take the sliced portion i.e. from page 87 to 565 of the pdf dictionary list#####

# %%
# Load data (deserialize)
with open('pdf_content_dict_page_final.pickle', 'rb') as handle:
    document_dict_deserialized = pickle.load(handle)
